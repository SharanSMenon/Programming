# %% [markdown]
# # Matplotlib examples
# ***

# %% [markdown]
# ## Background info
# ### Markers
# All markers can be found here: https://matplotlib.org/api/markers_api.html.
# ### Styles
# All styles can be found here: https://tonysyu.github.io/raw_content/matplotlib-style-gallery/gallery.html

# %%
#Import
import numpy as np
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
import matplotlib.style as style
style.use("ggplot")
# %matplotlib inline

# %% [markdown]
# ## Graphing 2 datasets

# %%
#Data
x = [1,2,3,4,5,6]
y = [2,6,4,5,1,3]

# %% [markdown]
# ### Scatterplot

# %%
plt.scatter(x,y)
plt.show()

# %% [markdown]
# ### Line graph

# %%
plt.plot(x,y)
plt.show()

# %% [markdown]
# ## Graphing functions

# %% [markdown]
# ### Graphing Quadratic functions

# %%
x = np.array(range(-11,10)) 
y = eval("x**2+2*x+2")
print(y)
plt.xlabel("X")
plt.ylabel("f(x)")
axes = plt.gca()
axes.set_xlim([-12,10])
# axes.set_xscale("log")
# axes.set_autoscaley_on(False)
plt.plot(x,y)

plt.show()
# Out:
# [101  82  65  50  37  26  17  10   5   2   1   2   5  10  17  26  37  50
#   65  82 101]

# %% [markdown]
# ### Graphing Exponential functions

# %%
x = np.array(range(0,10)) 
y = eval("2**x")
print(y)
plt.xlabel("X")
plt.ylabel("f(x)")
axes = plt.gca()
axes.set_xlim([0,10])
plt.plot(x,y)
plt.show()
# Out:
# [  1   2   4   8  16  32  64 128 256 512]

# %% [markdown]
# ### Graphing linear functions

# %%
x = np.array(range(0,10)) 
y = eval("2*x")
plt.xlabel("X")
plt.ylabel("f(x)")
axes = plt.gca()
axes.set_xlim([0,10])
plt.plot(x,y)
plt.show()

# %% [markdown]
# ## K-Means cluster example
# Clustering Data into datasets

# %%
#Import K-means algorithm
from sklearn.cluster import KMeans

# %%
#Data
X = np.array([[1,2],
             [5,8],
             [1.5,1.8],
             [8,8],
             [1,0.6],
             [9,11]])
kmeans = KMeans(n_clusters=2)
kmeans.fit(X)
centroids = kmeans.cluster_centers_
labels = kmeans.labels_
colors = ["g.","b."]
for i in range(len(X)):
    plt.plot(X[i][0],X[i][1],colors[labels[i]],markersize=10)
plt.scatter(centroids[:,0],centroids[:,1],marker="x",s=150,linewidths=5,zorder=10)
plt.show()

# %% [markdown]
# ## 3d Graphs
# Creating 3d graphs.
# 3d graphs require x,y,and z

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
n = 10
x = [1,2,3,4,5,6]
y = [4,5,1,6,3,2]
z = [3,2,5,4,1,6]
ax.scatter(x, y, z, c="r", marker="x")

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
# Out:
# Text(0.5,0,'Z')

# %%
plt.show()

# %% [markdown]
# You can still do 2d graphs after creating a 3d graph

# %%
plt.scatter(x,y,marker="o",c="g")
plt.xlabel("x")
plt.ylabel("y")
plt.show()
#Note: I just took x and y from the previous cell. It was already defined there

# %% [markdown]
# ## Bar graphs

# %%
objects = ["Sharan","Anu","Sajiv","Jahnvi"]
age = [12,37,41,8]
colors = ["r","g","b","y"]
plt.bar(objects,age,align='center',alpha=0.5,color=colors)
# plt.xticks(objects, objects)
plt.ylabel('Age')
plt.xlabel('Family Member')
plt.title('Ages of family members')
 
plt.show()

# %% [markdown]
# # Graphing multiple lines and creating a legend
# In this example, 3 functions are being graphed: A linear, exponential, and a quadratic function.
# There is a legend showing in the upper left corner to help identify the lines.

# %%
x = np.array(range(0,10))
y1 = eval("8*x")
y2 = eval("1.7**x")
y3 = eval("x**2")
axes = plt.gca()
axes.set_xlim([0,10])
red_label = mpatches.Patch(color='red', label='y = 8x (Linear)')
blue_label = mpatches.Patch(color='blue', label='y = x**2 (Quadratic)')
green_label = mpatches.Patch(color='green', label='y = 1.7**x (Exponential)')
plt.legend(handles=[red_label,green_label,blue_label])
plt.plot(x,y1,color='red',label='Line 2')
plt.plot(x,y2,color='green')
plt.plot(x,y3,color='blue')

# %% [markdown]
# # Creating random data to graph

# %%
from numpy.random import randn

# %%
# K-means clustering will be used to cluster this data
x = randn(100)
y = randn(100)
X = np.array([[x[i], y[i]] for i in range(0,len(x))])

# %%
# 4 clusters were created
kmeans = KMeans(n_clusters=4)
kmeans.fit(X)
centroids = kmeans.cluster_centers_
labels = kmeans.labels_
colors = ["g.","b.","c.","y."]
for i in range(len(X)):
    plt.plot(X[i][0],X[i][1],colors[labels[i]],markersize=10)
plt.scatter(centroids[:,0],centroids[:,1],marker="x",s=150,linewidths=5,zorder=10)
