# %%
import numpy as np
import random as randn
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline
df = pd.DataFrame(np.random.randn(100, 4),columns='A B C D'.split())
df.head()
# Out:
#           A         B         C         D
# 0  0.550816 -0.188680  1.046110  0.116614
# 1  1.228184  2.280035  1.384658  0.641365
# 2 -0.944040  1.316344  0.951118  0.533451
# 3  0.808126  0.546990 -0.479640  1.580783
# 4 -0.357305 -0.960270 -0.949295  1.231753

# %%
df2 = pd.DataFrame({"Category":"A B C".split(),"Values":[124,423,234]})
df2
# Out:
#   Category  Values
# 0        A     124
# 1        B     423
# 2        C     234

# %%
df.plot()

# %%
df.sum().plot(kind='bar')

# %%
df['A'].plot(kind='hist',edgecolor='black')

# %%
df2.plot(kind='pie',y='Values',autopct="%0.2f%%")
plt.axis('equal')
# Out:
# (-1.102401268709154,
#  1.100114377045206,
#  -1.1134589541529356,
#  1.1111763958759644)

# %%
df.plot(kind='box')
plt.legend("A B C D".split())
