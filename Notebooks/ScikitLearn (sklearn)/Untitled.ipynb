# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sklearn.datasets import make_blobs

# %%
data = make_blobs(n_samples=200,n_features=2,centers=4,cluster_std=1.8,
                 random_state=101)

# %%
plt.style.use("ggplot")
plt.scatter(data[0][:,0],data[0][:,1],c=data[1])

# %%
# K-means clustering
from sklearn.cluster import KMeans

# %%
# Unsupervised machine learning algorithm
kmeans = KMeans(n_clusters=4)

# %%
kmeans.fit(data[0])
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=4, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
kmeans.cluster_centers_[4]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-50-436f237cd0d3> in <module>()
# ----> 1 kmeans.cluster_centers_[4]
#
# IndexError: index 4 is out of bounds for axis 0 with size 4

# %%
kmeans.labels_
# Out:
# array([0, 3, 1, 3, 3, 2, 3, 1, 3, 1, 0, 1, 3, 3, 0, 1, 3, 1, 2, 0, 2, 1, 1,
#        2, 0, 2, 2, 1, 3, 3, 0, 2, 3, 1, 1, 0, 2, 2, 2, 1, 2, 0, 0, 0, 1, 3,
#        0, 1, 2, 1, 1, 0, 3, 1, 2, 0, 1, 1, 0, 3, 2, 3, 2, 0, 3, 1, 2, 3, 3,
#        2, 3, 1, 2, 1, 2, 3, 3, 1, 0, 1, 1, 2, 3, 2, 1, 1, 1, 0, 1, 2, 2, 2,
#        2, 1, 1, 2, 3, 0, 2, 3, 1, 2, 1, 1, 3, 1, 2, 3, 2, 2, 3, 0, 0, 3, 2,
#        3, 0, 0, 3, 0, 1, 0, 1, 0, 1, 3, 0, 1, 2, 0, 0, 0, 1, 2, 2, 0, 3, 0,
#        3, 1, 2, 3, 2, 0, 0, 3, 1, 2, 0, 0, 0, 0, 1, 3, 1, 0, 3, 3, 3, 1, 3,
#        1, 1, 0, 2, 0, 1, 3, 0, 1, 3, 1, 0, 3, 1, 0, 3, 3, 2, 3, 0, 2, 2, 0,
#        2, 2, 2, 2, 2, 1, 2, 3, 3, 0, 2, 1, 3, 3, 2, 1])

# %%
fig, (ax1,ax2) = plt.subplots(1,2,sharey=True,figsize=(10,6))
ax1.set_title('K Means')
ax1.scatter(data[0][: ,0],data[0][: ,1],c=kmeans.labels_,cmap='rainbow')
# ax1.scatter(kmeans.cluster_centers_[0:4][0],kmeans.cluster_centers_[0:4][1],marker='x',c='r',s=320)
ax2.set_title('Original')
ax2.scatter(data[0][: ,0],data[0][: ,1],c=data[1],cmap='rainbow')
